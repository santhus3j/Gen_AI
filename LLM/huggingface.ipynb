# %%
# Hugging Face token example
import os
print("HF_TOKEN is configured" if os.getenv("HF_TOKEN") else "HF_TOKEN is not set")

# %%
# !pip install requests

# %%
import os
print(os.getenv('HF_TOKEN'))

# %%
import os
import requests

API_URL = "https://router.huggingface.co/v1/chat/completions"
headers = {
    "Authorization": f"Bearer {os.getenv('HF_TOKEN')}",
}


'''
Payload   =   
    "messages": [
        {
            "role": "user",
            "content": "What is the capital of France?"
        }
    ],
    "model": "deepseek-ai/DeepSeek-R1:novita"
})'''


def query(payload):
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.json()

response = query({
    "messages": [
        {
            "role": "user",
            "content": "What is the capital of France?"
        }
    ],
    "model": "deepseek-ai/DeepSeek-R1:novita"
})

print(response)

# %%
print(response['choices'][0]['message']['content'])

# %%
import os
import requests

API_URL = "https://router.huggingface.co/featherless-ai/v1/completions"
headers = {
    "Authorization": f"Bearer {os.getenv('HF_TOKEN')}",
}

def query(payload):
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.json()

output = query({
    "inputs": 'which is the capital city of india?'
})
print(output)
# Mistral-7B-v0.1

# %%
import os
import requests

API_URL = "https://router.huggingface.co/v1/chat/completions"
headers = {
    "Authorization": f"Bearer {os.getenv('HF_TOKEN')}",
}

def query(payload):
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.json()

response = query({
    "messages": [
        {
            "role": "user",
            "content": "What is the capital of France?"
        }
    ],
    "model": "openai/gpt-oss-20b:groq"
})

print(response["choices"][0]["message"]['content'])

# openai/gpt-oss-20b

# %%
import os
import requests

API_URL = "https://router.huggingface.co/featherless-ai/v1/completions"
headers = {
    "Authorization": f"Bearer {os.getenv('HF_TOKEN')}",
}

def query(payload):
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.json()

output = query({
    "inputs": 'capital of france'
})
# oogle/gemma-7b
