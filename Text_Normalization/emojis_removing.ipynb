# %%
import emoji

# %%
# !pip install emoji
# Out:
# ...
#    ---------------------------------------- 0.0/608.4 kB ? eta -:--:--
#    ---------------------------------------- 0.0/608.4 kB ? eta -:--:--
#    ---------------------------------------- 0.0/608.4 kB ? eta -:--:--
#    ---------------------------------------- 608.4/608.4 kB 3.5 MB/s  0:00:00
# ...

# %%
s = 'Hi 😍🤷‍♂️🎶😜🥰🥸👻🙈🤌'
print(emoji.demojize(s), sep = '\n')

# %%
# what is sentiment analysis
''' '''
