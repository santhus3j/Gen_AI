# %%
from textblob import TextBlob

# %%
# !pip install textblob

# %%
text = 'corrting the wods for txt normalization'
text1 = 'i havv the wods for txt normaliation'

corrected_words = TextBlob(text1)
print(corrected_words, type(corrected_words))
# Out:
# corret the wods for txt normaliation <class 'textblob.blob.TextBlob'>
